# %%
#A list of shops
names = ["Vibe Vault","Sola Mode","Aura Attire","Glow Theory"]
landmark = ["402 Urban Lane","321 High Street","709 Soho Boulevard","204 Edge Lane"]
#Print each shop's landmark

for i in range(len(names)):
  print ( names[i], "roadmarks",landmark[i] )

#How many shops do we have ?
print("Total shops:",len(names))
#What is the first shop?
print(" First shop:",names[0])
#What is the last shop?
print("last shop:",names[-1])
# Out:
# Vibe Vault roadmarks 402 Urban Lane
# Sola Mode roadmarks 321 High Street
# Aura Attire roadmarks 709 Soho Boulevard
# Glow Theory roadmarks 204 Edge Lane
# Total shops: 4
#  First shop: Vibe Vault
# last shop: Glow Theory
